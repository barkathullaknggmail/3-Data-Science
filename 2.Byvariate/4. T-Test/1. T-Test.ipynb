# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("Preplacement.csv")
dataset
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3    56.00  52.00     52.00     66.0  59.43  265000.0      M  Central
# 4    85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 210  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  62.00  58.00     53.00     89.0  60.22  265000.0      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
dataset=dataset.dropna()
dataset
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3    56.00  52.00     52.00     66.0  59.43  265000.0      M  Central
# 4    85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 210  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  62.00  58.00     53.00     89.0  60.22  265000.0      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
dataset[dataset['gender']=='M']
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3    56.00  52.00     52.00     66.0  59.43  265000.0      M  Central
# 4    85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 209  62.00  72.00     65.00     67.0  56.49  216000.0      M  Central
# 210  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 214  62.00  58.00     53.00     89.0  60.22  265000.0      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
dataset[dataset['gender']=='F']
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 6    46.00   49.2      79.0    74.28  53.29  265000.0      F   Others
# 12   47.00   55.0      65.0    62.00  65.04  265000.0      F  Central
# 13   77.00   87.0      59.0    68.00  68.63  218000.0      F  Central
# 15   65.00   75.0      69.0    72.00  64.66  200000.0      F  Central
# 17   55.00   67.0      64.0    60.00  67.28  265000.0      F  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 197  83.96   53.0      91.0    59.32  69.71  260000.0      F   Others
# 198  67.00   70.0      65.0    88.00  71.96  265000.0      F  Central
# 204  74.00   73.0      73.0    80.00  67.69  210000.0      F   Others
# 208  43.00   60.0      65.0    92.66  62.92  265000.0      F  Central
# 213  74.00   66.0      58.0    70.00  60.23  204000.0      F   Others
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %% [markdown]
# # Independent Paired T-Test
# # Different group(male, female) but same condition(salary)

# %% [markdown]
# # Similarity between Male and Female Salary

# %%
dataset[dataset['gender']=='M']['salary']
# Out:
# 0      270000.0
# 1      200000.0
# 2      250000.0
# 3      265000.0
# 4      425000.0
#          ...
# 209    216000.0
# 210    400000.0
# 211    275000.0
# 212    295000.0
# 214    265000.0
# Name: salary, Length: 139, dtype: float64

# %%
dataset[dataset['gender']=='F']['salary']
# Out:
# 6      265000.0
# 12     265000.0
# 13     218000.0
# 15     200000.0
# 17     265000.0
#          ...
# 197    260000.0
# 198    265000.0
# 204    210000.0
# 208    265000.0
# 213    204000.0
# Name: salary, Length: 76, dtype: float64

# %%
male=dataset[dataset['gender']=='M']['salary']
female=dataset[dataset['gender']=='F']['salary']
print("Male Salary",male)
print("FeMale Salary",female)
# Out:
# Male Salary 0      270000.0
# 1      200000.0
# 2      250000.0
# 3      265000.0
# 4      425000.0
#          ...
# 209    216000.0
# 210    400000.0
# 211    275000.0
# 212    295000.0
# 214    265000.0
# Name: salary, Length: 139, dtype: float64
# FeMale Salary 6      265000.0
# 12     265000.0
# 13     218000.0
# 15     200000.0
# 17     265000.0
#          ...
# 197    260000.0
# 198    265000.0
# 204    210000.0
# 208    265000.0
# 213    204000.0
# Name: salary, Length: 76, dtype: float64

# %%
from scipy.stats import ttest_ind
ttest_ind(male,female)
# Out:
# TtestResult(statistic=2.071926593611645, pvalue=0.039476501699222566, df=213.0)

# %% [markdown]
# # p <0.05 so Reject Null Hypothesis and accept alternate hypothesis

# %% [markdown]
# # Interprete : There are  significant different between Male and Female Salary

# %% [markdown]
# # Similarity between Cenral and others board Salary

# %%
dataset[dataset['hsc_b']== 'Others'	]['salary']
# Out:
# 0      270000.0
# 1      200000.0
# 5      265000.0
# 6      265000.0
# 12     265000.0
#          ...
# 210    400000.0
# 211    275000.0
# 212    295000.0
# 213    204000.0
# 214    265000.0
# Name: salary, Length: 131, dtype: float64

# %%
dataset[dataset['hsc_b']== 'Central']['salary']
# Out:
# 2      250000.0
# 3      265000.0
# 4      425000.0
# 7      252000.0
# 8      231000.0
#          ...
# 195    275000.0
# 198    265000.0
# 202    240000.0
# 206    265000.0
# 209    216000.0
# Name: salary, Length: 84, dtype: float64

# %%
cen=dataset[dataset['hsc_b']== 'Central']['salary']
ncen=dataset[dataset['hsc_b']== 'Others']['salary']

# %%
from scipy.stats import ttest_ind
ttest_ind(cen,ncen)
# Out:
# TtestResult(statistic=0.05555765325089362, pvalue=0.9557462783338404, df=213.0)

# %% [markdown]
# # p>0.05 so Accept Null Hypothesis

# %% [markdown]
# # Intereprete : There are no significant diferent between Central and other board student salary package

# %% [markdown]
# # Dependent Paired T-Test
# # Group(same -categorical data) but different condition(hsc_p,ssc_p Numerical data)

# %%
male1=dataset[dataset['gender']=='M']['ssc_p']
male2=dataset[dataset['gender']=='M']['hsc_p']
ttest_ind(male1,male2)
# Out:
# TtestResult(statistic=0.462536606114424, pvalue=0.6440609938866582, df=276.0)

# %% [markdown]
# # p >0.05 so accept Null hypothesis

# %% [markdown]
# # INTEREPRETE : THERE ARE NO SIGNIFICANT DIFFERENT BETWEEN 10TH AND PLUS TWO MARKE OF MALE STUDENT

# %% [markdown]
# # Similarity between MBA and Etest mark in Commerce Student

# %%
dataset[dataset['degree_t']=='Comm&Mgmt']['mba_p']
# Out:
# 2      57.80
# 4      55.50
# 6      53.29
# 8      61.29
# 9      52.21
#        ...
# 209    56.49
# 210    74.49
# 212    69.72
# 213    60.23
# 214    60.22
# Name: mba_p, Length: 145, dtype: float64

# %%
dataset[dataset['degree_t']=='Comm&Mgmt']['etest_p']
# Out:
# 2      75.00
# 4      96.80
# 6      74.28
# 8      91.34
# 9      54.00
#        ...
# 209    67.00
# 210    91.00
# 212    59.00
# 213    70.00
# 214    89.00
# Name: etest_p, Length: 145, dtype: float64

# %%
mba=dataset[dataset['degree_t']=='Comm&Mgmt']['mba_p']
etest=dataset[dataset['degree_t']=='Comm&Mgmt']['etest_p']
ttest_ind(mba,etest)
# Out:
# TtestResult(statistic=-8.371116180455038, pvalue=2.513497844777739e-15, df=288.0)

# %% [markdown]
# # p < 0.05 so Reject null hypothesis

# %% [markdown]
# # Intereprete : There are significant diferent between MBA marks and entrance test marks of Commerse and Management group student
