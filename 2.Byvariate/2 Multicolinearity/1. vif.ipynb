# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("Preplacement.csv")
dataset
# Out:
#      ssc_p  hsc_p  degree_p  etest_p  mba_p    salary gender    ssc_b  \
# 0    67.00  91.00     58.00     55.0  58.80  270000.0      M   Others
# 1    79.33  78.33     77.48     86.5  66.28  200000.0      M  Central
# 2    65.00  68.00     64.00     75.0  57.80  250000.0      M  Central
# 3    56.00  52.00     52.00     66.0  59.43  265000.0      M  Central
# 4    85.80  73.60     73.30     96.8  55.50  425000.0      M  Central
# ..     ...    ...       ...      ...    ...       ...    ...      ...
# 210  80.60  82.00     77.60     91.0  74.49  400000.0      M   Others
# 211  58.00  60.00     72.00     74.0  53.62  275000.0      M   Others
# 212  67.00  67.00     73.00     59.0  69.72  295000.0      M   Others
# 213  74.00  66.00     58.00     70.0  60.23  204000.0      F   Others
# 214  62.00  58.00     53.00     89.0  60.22  265000.0      M  Central
#
#        hsc_b     hsc_s   degree_t workex specialisation      status
# ...

# %%
["ssc_p","hsc_p","degree_p","etest_p","mba_p","salary"]
# Out:
# ['ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
dataset.isnull().sum()
# Out:
# ssc_p             0
# hsc_p             0
# degree_p          0
# etest_p           0
# mba_p             0
# salary            0
# gender            0
# ssc_b             0
# hsc_b             0
# hsc_s             0
# degree_t          0
# workex            0
# specialisation    0
# status            0
# dtype: int64

# %%
# dataset.drop[('slno',inplace=True, axis=1)

# %%
import seaborn as sns
sns.pairplot(dataset)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def calc_vif(x):
        #Calculating VIF
    vif = pd.DataFrame()
    vif["variables"]=x.columns
    
    vif["VIF"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]

    return(vif)

# %%
# Pass only quantitative data
calc_vif(dataset[["ssc_p","hsc_p","degree_p","etest_p","mba_p","salary"]])
# Out:
#   variables         VIF
# 0     ssc_p   66.968237
# 1     hsc_p   56.268303
# 2  degree_p  112.717328
# 3   etest_p   33.511435
# 4     mba_p  104.464763
# 5    salary   14.432677

# %%
calc_vif(dataset[["etest_p","salary"]])
# Out:
#   variables        VIF
# 0   etest_p  11.595795
# 1    salary  11.595795

# %%
calc_vif(dataset[["salary","etest_p"]])
# Out:
#   variables        VIF
# 0    salary  11.595795
# 1   etest_p  11.595795

# %%
calc_vif(dataset[["salary","hsc_p"]])
# Out:
#   variables       VIF
# 0    salary  11.67638
# 1     hsc_p  11.67638
